# %%
from valis import slide_io
# import os
# os.environ['PATH'] += ":/home/yuanmingze/softwares/apache-maven-3.9.4/bin"

slide_src_f = "/home/yuanmingze/data/mIF_175/P1/Image_222476-P1-01.vsi"
# slide_src_f = '/home/yuanmingze/data/mIF_P1_demo/_Image_222476-P1-01_/stack1/frame_t.ets'
# slide_src_f = '/home/yuanmingze/data/mIF_P1_demo_ets/P1_01.ets'
series = 2

# Get reader for slide format
reader_cls = slide_io.get_slide_reader(slide_src_f, series=series) #Get appropriate slide reader class
reader = reader_cls(slide_src_f, series=series) # Instantiate reader

#Get size of images in each pyramid level (width, height)
pyramid_level_sizes_wh = reader.metadata.slide_dimensions
print(pyramid_level_sizes_wh)
# Out:
# [[988 502]
#  [322 239]
#  [ 45  47]]

# %%
import os
data_dir = '/public/share/ymz/valisProject/data/mIF_175_organized'
dict_fname = {'Patient': sorted(os.listdir(data_dir), key=lambda x: int(x[1:]))}

# %%
from pandas import DataFrame
df_fname = DataFrame(dict_fname)
df_fname.to_excel('/home/yuanmingze/tmp/mIF_175_id.xlsx', index=False)

# %%
reader.series
# Out:
# 0

# %%
from valis.slide_tools import determine_if_staining_round
src_dir = '/home/yuanmingze/data/mIF_P1_demo/_Image_222476-P1-01_'
src_dir = '/home/yuanmingze/data/mIF_P1_demo/_Image_222476-P1-01_/stack1'
determine_if_staining_round(src_dir)
# Out:
# (False, None)

# %%
reader.series
# Out:
# 0

# %%
img = reader.slide2image(level=0)
img.shape
# Out:
# (375, 991, 3)

# %%
# from valis import slide_io
# slide_src_f = "/home/yuanmingze/data/mIF_P1_demo/_Image_222476-P1-01_/stack1/frame_t.ets"
# converted_slide_f = "/home/yuanmingze/tmp/P1_01.ome.tiff"
# slide_io.convert_to_ome_tiff(slide_src_f,
#                              converted_slide_f,
#                              level=0)
# slide_io.kill_jvm()

# %%
reader.metadata.channel_names
# Out:
# ['DAPI', 'PPD 480', 'PPD 520', 'PPD 570', 'PPD 650', 'PPD 780']

# %%
import matplotlib.pyplot as plt

# %%
reader.metadata.n_channels
# Out:
# 6

# %%
reader.metadata.name
# Out:
# 'Image_222476-P1-01.vsi_Series(0)'

# %%
reader.metadata.bf_pixel_type
# Out:
# '3'

# %%
reader.metadata.bf_datatype
# Out:
# 'uint16'

# %%
img = reader.slide2image(level=0)
img.shape
plt.imshow(img)

# %%
img = reader.slide2image(level=1)
img.shape
plt.imshow(img)

# %%
img = reader.slide2image(level=2)
img.shape
plt.imshow(img)

# %%
img = reader.slide2image(level=3)
img.shape
# plt.imshow(img)
# Out:
# (502, 988)

# %%
plt.imshow(img, cmap='gray')

# %%
img = reader.slide2image(level=4)
img.shape
plt.imshow(img)

# %%
img = reader.slide2image(level=5)
img.shape
# Out:
# (47, 45)

# %%
# Get full resolution image as a pyvips.Image
full_rez_vips = reader.slide2vips(level=4)
full_rez_vips.width, full_rez_vips.height
# Out:
# (322, 239)
